# %%
#데이터 로드와 인덱스 번호 제거 
import pandas as pd
import numpy as np 
df = pd.read_csv('data/user_spec.csv')
df
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 0               1249046   118218      1985.0     1.0  2022-06-07 06:28:18
# 1                954900   553686      1968.0     1.0  2022-06-07 14:29:03
# 2                137274    59516      1997.0     1.0  2022-06-07 21:40:22
# 3               1570936   167320      1989.0     1.0  2022-06-07 09:40:27
# 4                967833    33400      2000.0     1.0  2022-06-07 08:55:07
# ...                 ...      ...         ...     ...                  ...
# 1394211         1864587   489900      2000.0     1.0  2022-03-22 14:55:32
# 1394212         1327066   151422      1955.0     1.0  2022-03-22 01:19:24
# 1394213         1319606   173524      1983.0     1.0  2022-03-22 07:34:32
# 1394214         1482466   766546      1975.0     1.0  2022-03-22 22:12:35
# 1394215          816537     3864      1977.0     0.0  2022-03-22 08:55:14
#
#          credit_score  yearly_income      income_type  company_enter_month  \
# ...

# %%
df1=df.dropna(subset=['credit_score'])
df1
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 0               1249046   118218      1985.0     1.0  2022-06-07 06:28:18
# 1                954900   553686      1968.0     1.0  2022-06-07 14:29:03
# 2                137274    59516      1997.0     1.0  2022-06-07 21:40:22
# 3               1570936   167320      1989.0     1.0  2022-06-07 09:40:27
# 4                967833    33400      2000.0     1.0  2022-06-07 08:55:07
# ...                 ...      ...         ...     ...                  ...
# 1394210          316356    53701      1996.0     1.0  2022-03-22 10:01:38
# 1394211         1864587   489900      2000.0     1.0  2022-03-22 14:55:32
# 1394212         1327066   151422      1955.0     1.0  2022-03-22 01:19:24
# 1394213         1319606   173524      1983.0     1.0  2022-03-22 07:34:32
# 1394214         1482466   766546      1975.0     1.0  2022-03-22 22:12:35
#
#          credit_score  yearly_income      income_type  company_enter_month  \
# ...

# %%
df1=df1.dropna(subset=['birth_year'])
df1
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 0               1249046   118218      1985.0     1.0  2022-06-07 06:28:18
# 1                954900   553686      1968.0     1.0  2022-06-07 14:29:03
# 2                137274    59516      1997.0     1.0  2022-06-07 21:40:22
# 3               1570936   167320      1989.0     1.0  2022-06-07 09:40:27
# 4                967833    33400      2000.0     1.0  2022-06-07 08:55:07
# ...                 ...      ...         ...     ...                  ...
# 1394210          316356    53701      1996.0     1.0  2022-03-22 10:01:38
# 1394211         1864587   489900      2000.0     1.0  2022-03-22 14:55:32
# 1394212         1327066   151422      1955.0     1.0  2022-03-22 01:19:24
# 1394213         1319606   173524      1983.0     1.0  2022-03-22 07:34:32
# 1394214         1482466   766546      1975.0     1.0  2022-03-22 22:12:35
#
#          credit_score  yearly_income      income_type  company_enter_month  \
# ...

# %%
df1.isnull().sum()
# Out:
# application_id                               0
# user_id                                      0
# birth_year                                   0
# gender                                       0
# insert_time                                  0
# credit_score                                 0
# yearly_income                               84
# income_type                                 80
# company_enter_month                     151961
# employment_type                             80
# houseown_type                               80
# desired_amount                              80
# purpose                                     80
# personal_rehabilitation_yn              527835
# personal_rehabilitation_complete_yn    1107899
# existing_loan_cnt                       117663
# existing_loan_amt                       229611
# dtype: int64

# %%
df1.info()

# %%
df1['company_enter_month'] = df1['company_enter_month'].astype(str)
df1['enter_month']=df1['company_enter_month'].str[:6]
df1
# Out:
# /var/folders/nz/160bjb610xj3r4wkpjkgnw940000gn/T/ipykernel_3988/1089413972.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['company_enter_month'] = df1['company_enter_month'].astype(str)
# /var/folders/nz/160bjb610xj3r4wkpjkgnw940000gn/T/ipykernel_3988/1089413972.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['enter_month']=df1['company_enter_month'].str[:6]
#          application_id  user_id  birth_year  gender          insert_time  \
# ...

# %%
df1['enter_month'] = df1['enter_month'].astype(float)
df1=df1.dropna(subset=['enter_month'])
df1
# Out:
# /var/folders/nz/160bjb610xj3r4wkpjkgnw940000gn/T/ipykernel_3988/3790465887.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['enter_month'] = df1['enter_month'].astype(float)
#          application_id  user_id  birth_year  gender          insert_time  \
# 0               1249046   118218      1985.0     1.0  2022-06-07 06:28:18
# 1                954900   553686      1968.0     1.0  2022-06-07 14:29:03
# 2                137274    59516      1997.0     1.0  2022-06-07 21:40:22
# 3               1570936   167320      1989.0     1.0  2022-06-07 09:40:27
# 4                967833    33400      2000.0     1.0  2022-06-07 08:55:07
# ...                 ...      ...         ...     ...                  ...
# ...

# %%
df1['year']=202206
df1
# Out:
# /var/folders/nz/160bjb610xj3r4wkpjkgnw940000gn/T/ipykernel_3988/1384796790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['year']=202206
#          application_id  user_id  birth_year  gender          insert_time  \
# 0               1249046   118218      1985.0     1.0  2022-06-07 06:28:18
# 1                954900   553686      1968.0     1.0  2022-06-07 14:29:03
# 2                137274    59516      1997.0     1.0  2022-06-07 21:40:22
# 3               1570936   167320      1989.0     1.0  2022-06-07 09:40:27
# 4                967833    33400      2000.0     1.0  2022-06-07 08:55:07
# ...                 ...      ...         ...     ...                  ...
# ...

# %%
df1['enter_month'] = df1['enter_month'].astype(int)
df1
# Out:
# /var/folders/nz/160bjb610xj3r4wkpjkgnw940000gn/T/ipykernel_3988/3874855589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['enter_month'] = df1['enter_month'].astype(int)
#          application_id  user_id  birth_year  gender          insert_time  \
# 0               1249046   118218      1985.0     1.0  2022-06-07 06:28:18
# 1                954900   553686      1968.0     1.0  2022-06-07 14:29:03
# 2                137274    59516      1997.0     1.0  2022-06-07 21:40:22
# 3               1570936   167320      1989.0     1.0  2022-06-07 09:40:27
# 4                967833    33400      2000.0     1.0  2022-06-07 08:55:07
# ...                 ...      ...         ...     ...                  ...
# ...

# %%
df1=df1.dropna(subset=['income_type'])
df1
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 0               1249046   118218      1985.0     1.0  2022-06-07 06:28:18
# 1                954900   553686      1968.0     1.0  2022-06-07 14:29:03
# 2                137274    59516      1997.0     1.0  2022-06-07 21:40:22
# 3               1570936   167320      1989.0     1.0  2022-06-07 09:40:27
# 4                967833    33400      2000.0     1.0  2022-06-07 08:55:07
# ...                 ...      ...         ...     ...                  ...
# 1394209          256365   762698      1994.0     1.0  2022-03-22 14:42:04
# 1394210          316356    53701      1996.0     1.0  2022-03-22 10:01:38
# 1394211         1864587   489900      2000.0     1.0  2022-03-22 14:55:32
# 1394213         1319606   173524      1983.0     1.0  2022-03-22 07:34:32
# 1394214         1482466   766546      1975.0     1.0  2022-03-22 22:12:35
#
#          credit_score  yearly_income      income_type company_enter_month  \
# ...

# %%
df1=df1.dropna(subset=['gender'])
df1
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 0               1249046   118218      1985.0     1.0  2022-06-07 06:28:18
# 1                954900   553686      1968.0     1.0  2022-06-07 14:29:03
# 2                137274    59516      1997.0     1.0  2022-06-07 21:40:22
# 3               1570936   167320      1989.0     1.0  2022-06-07 09:40:27
# 4                967833    33400      2000.0     1.0  2022-06-07 08:55:07
# ...                 ...      ...         ...     ...                  ...
# 1394209          256365   762698      1994.0     1.0  2022-03-22 14:42:04
# 1394210          316356    53701      1996.0     1.0  2022-03-22 10:01:38
# 1394211         1864587   489900      2000.0     1.0  2022-03-22 14:55:32
# 1394213         1319606   173524      1983.0     1.0  2022-03-22 07:34:32
# 1394214         1482466   766546      1975.0     1.0  2022-03-22 22:12:35
#
#          credit_score  yearly_income      income_type company_enter_month  \
# ...

# %%
df1.isnull().sum()
# Out:
# application_id                              0
# user_id                                     0
# birth_year                                  0
# gender                                      0
# insert_time                                 0
# credit_score                                0
# yearly_income                               1
# income_type                                 0
# company_enter_month                         0
# employment_type                             0
# houseown_type                               0
# desired_amount                              0
# purpose                                     0
# personal_rehabilitation_yn             468312
# personal_rehabilitation_complete_yn    975955
# existing_loan_cnt                      101386
# existing_loan_amt                      196659
# enter_month                                 0
# year                                        0
# dtype: int64

# %%
from datetime import datetime
import time

# %%
df1['enter_month'] = pd.to_datetime(df1['enter_month'])
df1['year'] = pd.to_datetime(df1['year'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1125897 entries, 0 to 1394214
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count    Dtype
# ---  ------                               --------------    -----
#  0   application_id                       1125897 non-null  int64
#  1   user_id                              1125897 non-null  int64
#  2   birth_year                           1125897 non-null  float64
#  3   gender                               1125897 non-null  float64
#  4   insert_time                          1125897 non-null  object
#  5   credit_score                         1125897 non-null  float64
#  6   yearly_income                        1125896 non-null  float64
#  7   income_type                          1125897 non-null  object
#  8   company_enter_month                  1125897 non-null  object
#  9   employment_type                      1125897 non-null  object
# ...

# %%
df1['enter_month']=dt.strftime('%Y%m')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nz/160bjb610xj3r4wkpjkgnw940000gn/T/ipykernel_3988/2515493699.py in <module>
# ----> 1 df1['enter_month']=dt.strftime('%Y%m')
#
# NameError: name 'dt' is not defined
