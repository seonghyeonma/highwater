# %%
import os
import pandas as pd

# %%
df = pd.read_csv("user_spec_fin.csv")
df.head()
# Out:
#    application_id  user_id  gender  credit_score  yearly_income  \
# 0         1249046   118218     1.0         660.0    108000000.0
# 1          954900   553686     1.0         870.0     30000000.0
# 2          137274    59516     1.0         710.0     30000000.0
# 3         1570936   167320     1.0         820.0     62000000.0
# 4          967833    33400     1.0         630.0     36000000.0
#
#    desired_amount  personal_rehabilitation_yn  \
# 0       1000000.0                         0.0
# 1      30000000.0                         0.0
# 2      10000000.0                         0.0
# 3       2000000.0                         0.0
# 4       5000000.0                         0.0
#
#    personal_rehabilitation_complete_yn  existing_loan_cnt  existing_loan_amt  \
# 0                                  0.0                4.0        162000000.0
# 1                                  0.0         63708592.0         63708592.0
# 2                                  0.0                5.0         15000000.0
# 3                                  0.0                7.0        344000000.0
# 4                                  0.0         63708592.0         63708592.0
#
#    work_day   Age  label_purpose  label_employment_type  label_houseown_type  \
# 0      2404  37.0              0                      1                    2
# 1      5599  54.0              1                      3                    0
# 2       273  25.0              3                      1                    0
# 3      1977  33.0              3                      3                    2
# 4       273  22.0              3                      3                    0
#
#    label_income_type
# 0                  5
# 1                  5
# 2                  2
# 3                  0
# 4                  0

# %%
df.describe()
# Out:
#        application_id       user_id        gender  credit_score  \
# count    1.222456e+06  1.222456e+06  1.222456e+06  1.222456e+06
# mean     1.084052e+06  4.392500e+05  6.994722e-01  6.385154e+02
# std      6.258496e+05  2.536621e+05  4.584877e-01  1.200900e+02
# min      1.000000e+00  7.000000e+00  0.000000e+00  6.000000e+01
# 25%      5.418355e+05  2.202300e+05  0.000000e+00  5.700000e+02
# 50%      1.084196e+06  4.394210e+05  1.000000e+00  6.300000e+02
# 75%      1.625809e+06  6.586012e+05  1.000000e+00  6.800000e+02
# max      2.167826e+06  8.796970e+05  1.000000e+00  1.000000e+03
#
#        yearly_income  desired_amount  personal_rehabilitation_yn  \
# count   1.222456e+06    1.222456e+06                1.222456e+06
# mean    4.562435e+07    3.136851e+07                8.609717e-03
# std     1.163137e+08    1.772595e+08                9.238829e-02
# min     0.000000e+00    0.000000e+00                0.000000e+00
# 25%     2.700000e+07    5.000000e+06                0.000000e+00
# 50%     3.500000e+07    1.500000e+07                0.000000e+00
# 75%     5.000000e+07    3.000000e+07                0.000000e+00
# max     1.000000e+10    1.000000e+10                1.000000e+00
#
#        personal_rehabilitation_complete_yn  existing_loan_cnt  \
# count                         1.222456e+06       1.222456e+06
# mean                          9.071901e-04       5.582797e+06
# std                           3.010594e-02       1.801401e+07
# min                           0.000000e+00       0.000000e+00
# 25%                           0.000000e+00       2.000000e+00
# 50%                           0.000000e+00       4.000000e+00
# 75%                           0.000000e+00       7.000000e+00
# max                           1.000000e+00       6.370859e+07
#
#        existing_loan_amt      work_day           Age  label_purpose  \
# count       1.222456e+06  1.222456e+06  1.222456e+06   1.222456e+06
# mean        6.720697e+07  1.385929e+03  3.858754e+01   2.469164e+00
# std         8.416112e+07  1.893213e+03  1.021428e+01   1.175181e+00
# min         0.000000e+00 -1.530000e+02  1.500000e+01   0.000000e+00
# 25%         2.200000e+07  2.430000e+02  3.000000e+01   1.000000e+00
# 50%         5.600000e+07  6.380000e+02  3.800000e+01   3.000000e+00
# 75%         7.100000e+07  1.643000e+03  4.500000e+01   3.000000e+00
# max         7.512000e+09  4.456000e+04  8.900000e+01   7.000000e+00
#
#        label_employment_type  label_houseown_type  label_income_type
# count           1.222456e+06         1.222456e+06       1.222456e+06
# mean            2.425104e+00         1.801456e+00       8.184033e-01
# std             1.037786e+00         1.319073e+00       1.607455e+00
# min             0.000000e+00         0.000000e+00       0.000000e+00
# 25%             3.000000e+00         0.000000e+00       0.000000e+00
# 50%             3.000000e+00         2.000000e+00       0.000000e+00
# 75%             3.000000e+00         3.000000e+00       1.000000e+00
# max             3.000000e+00         3.000000e+00       5.000000e+00

# %%
df2 = pd.read_csv("loan_result_단위.csv")

# %%
import numpy as np
def IQR_rule(val_list): # 한 특징에 포함된 값 (즉, column과 대응되는 Series)
    # IQR 계산    
    Q1 = np.quantile(val_list, 0.25) # 25%값
    Q3 = np.quantile(val_list, 0.75) # 75%값
    IQR = Q3 - Q1
    
    # IQR rule을 위배하지 않는 bool list 계산 (True: 이상치 X, False: 이상치 O)
    not_outlier_condition = (Q3 + 1.5 * IQR > val_list) & (Q1 - 1.5 * IQR < val_list)
    return not_outlier_condition
